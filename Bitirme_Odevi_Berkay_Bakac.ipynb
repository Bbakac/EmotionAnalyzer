# %% [markdown]
# # **Tanıtım**

# %% [markdown]
# 1980 yılında Robert Plutchik, On Aksiyomları'ndan esinlenerek sekiz duygunun bir tekerlek diyagramını oluşturdu: sevinç, güven, korku, şaşkınlık, üzüntü, iğrenme, öfke ve beklenti. Plutchik ayrıca yirmi dört "Birincil", "İkincil" ve "Üçüncül" çift (iki duygudan oluşan hisler) teorize etti. Tekerlekteki duygular dört grupta eşleştirilebilir:
#
# Birincil çift = bir yaprak arası = Aşk = Sevinç + Güven
# İkincil çift = iki yaprak arası = Kıskançlık = Üzüntü + Öfke
# Üçüncül çift = üç yaprak arası = Utanç = Korku + İğrenme
# Zıt duygular = dört yaprak arası = Beklenti ≠ Şaşkınlık
# Bu duygusal tekerleğin duygu analiziyle bağlantısı, duyguların karmaşık ve ilişkili bir şekilde birbirine bağlı olduğunu gösterir. Duygusal tekerleğin çeşitli bileşenleri, duygusal analizde kullanılan algoritmaların geliştirilmesi ve duygusal içeriğin daha iyi anlaşılması için temel oluşturabilir. Örneğin, duygusal tekerleğin çiftleri, duygusal analiz modellerinde kullanılabilecek duygu çiftlerinin keşfedilmesine yol açabilir. Bu bağlamda, duygusal tekerleğin analizinde, duygular arasındaki ilişkileri ve duygusal içeriğin derinlemesine analizini içeren bir yaklaşım benimsenmelidir.

# %% [markdown]
# # **Veri ve Kütüphanelerin İçe Aktarılması**

# %%
# Bu Python 3 ortamı, birçok yardımcı analitik kütüphanesi ile birlikte gelir
# Kaggle/python docker görüntüsü tarafından tanımlanır: https://github.com/kaggle/docker-python
# Örneğin, yüklemek için birkaç faydalı paket şunlardır:

# NumPy, Python'da bilimsel hesaplamaları yapmak için kullanılan temel bir kütüphanedir.
import numpy as np # lineer cebir

# Pandas, veri analizi ve işleme için yaygın olarak kullanılan bir Python kütüphanesidir.
import pandas as pd # veri işleme, CSV dosya giriş/çıkışı (ör. pd.read_csv)

# Natural Language Toolkit (Doğal Dil İşleme Kütüphanesi), metin verileri üzerinde çalışmak için kullanılan bir kütüphanedir.
import nltk
#nltk.download()
#nltk.download('punkt')

# Seaborn, veri görselleştirme için kullanılan bir Python kütüphanesidir.
import seaborn as sns

# Matplotlib, grafikler ve görselleştirmeler oluşturmak için kullanılan bir Python kütüphanesidir.
import matplotlib.pyplot as plt

# Scikit-learn, Python'da makine öğrenimi için yaygın olarak kullanılan bir kütüphanedir.
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# Giriş veri dosyaları "/kaggle/input/" dizininde bulunmaktadır.
# Örneğin, burayı çalıştırmak (çalıştırma veya Shift+Enter'a basma) tüm dosyaları giriş dizininde listeler

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Şu anki dizine yazdığınız tüm sonuçlar çıktı olarak kaydedilir.

# %% [markdown]
# # **Veri Hakkında Bilgi Edinme**

# %%
# Veri setini yükle
dataset = pd.read_csv("/Users/berkaybakac/Downloads/data.csv")

# Veri setinin 100 tane satırını göster
display(dataset.head(10000)[::100])
pd.set_option('display.max_rows', None)
# Out:
#       Sl no                                             Tweets     Search key  \
# 0         1   #1: @fe ed "RT @MirayaDizon1: Time is ticking...  happy moments
# 100     101   #29: @small thing pjm 💜 ed "@BTS_twt HAVE FUN...        amazing
# 200     201   #49: @Eyewitness News ed "IEC satisfied with ...      satisfied
# 300     301   #73: @Emotions Invented by the Internet ed "T...      gratitude
# 400     401   #14: @nivan ed "RT @ChennaiIPL: Set the whist...          cheer
# 500     501   #34: @요한, 김. ed "Joy nunim! https://t.co/iAC3...            joy
# 600     601   #63: @kulsum404 ed "RT @CPMumbaiPolice: Wishi...     prosperity
# 700     701   #10: @عـبـدالرحـمـن . ed "@archi_x7 Happy bir...          happy
# 800     801   #39: @;💫 ed "@solo_jovial Uwi na dali puntaha...         jovial
# 900     901    #42: @Clyde Sithole ed "@Luyi_Blessed Sent...☺"        blessed
# 1000   1002   #65: @Mariposa🦋 ed "RT @myadevinee: So my boy...          enjoy
# 1100   1102   #2: @kehlani lovebot ed "RT @nazire_imeri: Y'...          lucky
# 1200   1202   #32: @chaeyoungstan ed "RT @cchaewzone: @Merc...        helpful
# 1300   1302   #40: @ɢιαɴ ed "RT @TheArtidote: Please don’t ...           good
# 1400   1402   #4: @ToMaKi ed "RT @FrappMocha: #Castlevania ...         sorrow
# 1500   1502   #24: @मैं अJAY भी चौकीदार ed "RT @TVMohandasP...         regret
# 1600   1602   #14: @Mike Sandoval ed "@JHabib10 He lost his...        depress
# 1700   1702   #44: @Colin Murray ed "RT @calvertoncc: A gen...      miserable
# 1800   1802   #74: @el🦒✡️ ed "essie, with a mournful sigh w...       mournful
# 1900   1902   #13: @Geoff Chinnock ex 💺 ed "@btsport @KESan...        trouble
# 2000   2002   #36: @Mar Antonette ed "Guilty kalang gid sil...         guilty
# 2100   2102   #55: @ivan aquise ed "RT @EW: Gwendoline Chri...          upset
# 2200   2202   #40: @literatura aplicada ed "RT @cassiomaia_...         tragic
# 2300   2302   #67: @𝓓𝓡.𝓛𝓘𝓥𝓢𝓘 ed "@linaiolanda В числе читае...           glum
# 2400   2402   #7: @Kaylee ed "Naka aircon tas gloomy weathe...         gloomy
# 2500   2502   #54: @𝓢𝓱𝓪𝓴𝓲𝓻𝓪𝓱 ☪ ‏شاكيره ed "RT @jjzalim: 4 M...            bad
# 2600   2602   #11: @Minseok where you going?!?! ed "RT @atz...          annoy
# 2700   2702   #31: @Onlyfor Adiza ed "RT @shikssays: If we ...       irritate
# 2800   2802   #23: @Scott White ed "RT @Sanjay_Dixit: Pract...        provoke
# 2900   2902   #28: @Seraphim ed "RT @richardhine: Obama del...        furious
# 3000   3002   #50: @Chris Palermo ed "@adignan @Starbucks @...         heated
# 3100   3102   #7: @Billrab ed "@RealSaavedra @vanessacvenus...       outraged
# 3200   3202   #28: @گمنام 🙋‍♂️ ed "RT @munsif_lashari: Kara...     aggravated
# 3300   3303   #34: @Zach Rongers ed "RT @shannonrwatts: The...           fear
# 3400   3403   #51: @maria alonso ed "RT @rociosanmiguel: Ha...         horror
# 3500   3503   #7: @Winnie Anon ed "RT @intheMatrixxx: Are y...          panic
# 3600   3603   #34: @Jennifer Slopez ed "@chestrovert When I...          scare
# 3700   3703   #62: @芦花 ed "@_stage_fright ですよ～！お待ちしてます！(*❛ั...         fright
# 3800   3803   #69: @Hend H. Mazhar ed "RT @9GAG: Dread it, ...          dread
# 3900   3903   #76: @Essie // The Skin Careless ed "Dodged a...        anxiety
# 4000   4004   #13: @The Donald Comes ed "M̹̩̜͓̪̖Ḁ̜KḘ͎ ̫̱͍͚A...         sicken
# 4100   4104   #38: @dsa otherkin caucus⌚ ed "RT @HeerJeet: ...      revulsion
# 4200   4204   #43: @TEXAS Capital ed "RT @Schuldensuehner: ...       aversion
# 4300   4304   #48: @ღ ed "RT @MayaDanielleP: The best way t...       distaste
# 4400   4404   #68: @percocet peat ed "Just threw up my anti...         nausea
# 4500   4504   #8: @bitch lasagna 🦝 ed "RT @BlackGirlNerds: ...          peace
# 4600   4604   #38: @Abdul Hadi ed "May Allah give us courag...        courage
# 4700   4704   #62: @liz andry ed "what i said was “brendon ...          brave
# 4800   4804   #27: @Dee is writing ed "RT @matthaig1: You a...           hope
# 4900   4904   #7: @Yog Bhooshan Maharaj ed "RT @moayush: By...        nervous
# 5000   5004   #28: @Rose Madonsela PFA ed "@mashrex @Mabore...           bold
# 5100   5104   #47: @Lisa Moorish 🤓 ed "RT @galaxaure: Well,...          harsh
# 5200   5204   #62: @Jamie Stewart ed "@TheSwissBankie Me re...           calm
# 5300   5304   #80: @Chak89 Fan Club ed "RT @irenaakbar: Dea...          faith
# 5400   5404   #21: @♡ ed "―impatient.yoongi walks to jimin ...         tensed
# 5500   5504   #48: @RAD DODG3Y (Dlive.tv) ed "@GRUNToEsport...          relax
# 5600   5604   #12: @KAN ed "@thelond0ner @Frimp_ Yooo we no...           bore
# 5700   5704   #42: @W. Clayton ed "@RitaPanahi @theheraldsu...           kind
# 5800   5804   #74: @partyturrtlee 🎉 🐢 ed "@chilly_duck Bro ...           envy
# 5900   5904   #23: @Rvku ed "@_azynne_ @Chika_Calvin @morga...           pity
# 6000   6004   #57: @zazazazaza ed "RT @DjaidaouiKamal: Il f...    indignation
# 6100   6104   #62: @Kai ed "RT @Krisabellim_: Self love wil...           love
# 6200   6204   #67: @WA Tri-Cities CCL ed "Action is the ant...        despair
# 6300   6304   #78: @Deep Upreti 🇮🇳 ed "RT @SadhguruJV: Devo...       devotion
# 6400   6404   #9: @The_Hatter ed "@KaijuWriterAnt It's most...      spiritual
# 6500   6504   #48: @Vicky D Vijayakumar ed "RT @LFC: Fight....  determination
# 6600   6604   #55: @Chimin ed "RT @OT7Rkive: He isn't Manag...            shy
# 6700   6704   #35: @🍀 OLÚWATÓYÌN🍀 ed "RT @IslamicTongue: Si...        modesty
# 6800   6804   #52: @nsh ed "RT @qilahrzli: Ramadhan? Fastin...          pride
# 6900   6904   #18: @mae✨ ed "RT @todorokth: manager sejin i...       patience
# 7000   7004   #37: @myah; ed "@dakseu17 @moonjuniekitty OHO...          loyal
# 7100   7104   #4: @princess ed "RT @filmfare: Here’s wishin...     very happy
# 7200   7204   #34: @tumbleweed ed "I’m so happy knowing eac...       so happy
# 7300   7304   #33: @Judgy Wudgy ed "@DuckyDangerous You ama...          amaze
# 7400   7404    #55: @Ali ed "@suddafchaudry The great escape."          great
# 7500   7504   #9: @miahdiary ed "RT @mahdylody: Episode 4 h...          shock
# 7600   7604   #23: @Dirt Orcas ed "RT @TheMarkTwain: Do the...       astonish
# 7700   7704   #60: @1 - Lavastorm - D-59111 ed "RT @Sir_GTa...           stun
# 7800   7804   #73: @眞琥 ed "RT @phujiwowmajuji: had to repos...           daze
# 7900   7904            #73: @チアフルキャンディ ed "今度のお休みにお菓子でも作ろうかな♪"       cheerful
# 8000   8004   #12: @chukwunazom ed "RT @OlamideQuadri4: Exc...     prosperous
# 8100   8104   #23: @Jose Lopes ed "It's May 08, 2019 at 08:...      happiness
# 8200   8204   #49: @Arya is the GOAT ed "RT @DvoElis: And j...          bless
# 8300   8304   #33: @Birgitta HedinCurtin ed "RT @slowfoodcl...      enjoyment
# 8400   8404   #66: @WGRZ ed "Soon-to-be mothers, ever thoug...           help
# 8500   8504   #23: @Ilkeston Advertiser ed "“Sorrowful” Der...      sorrowful
# 8600   8604  Tweet #54: @elaine tweeted "RT @EverlyneBabra:...     regretting
# 8700   8704  Tweet #69: @zeynep 🌤 tbz 1st win !! tweeted "R...      regretful
# 8800   8804  Tweet #17: @Far tweeted "RT @Godmade__: A very...       very sad
# 8900   8904  Tweet #37: @Nitah tweeted "@AsantejnrRuhima Y'...          mourn
# 9000   9004  Tweet #5: @Marcos B Lopez tweeted "@seanhannit...        hurting
# 9100   9104  Tweet #38: @lucas allen tweeted "RT @AnfieldHQ...      very hurt
# 9200   9204  Tweet #66: @Chowkidar Poonam K tweeted "RT @pu...      troubling
# 9300   9304  Tweet #16: @Harrison Pace tweeted "@googlenest...     very upset
# 9400   9404  Tweet #26: @Marufah Chavoos tweeted "RT @mufti...           pain
# 9500   9504  Tweet #60: @lucy cuzzupe tweeted "RT @cjjosh: ...        painful
# 9600   9604  Tweet #5: @Sir Creaky tweeted "RT @GraveyardBe...        weeping
# 9700   9704  Tweet #26: @Rock * Scooby Do not add me to lis...        tragedy
# 9800   9804  Tweet #43: @Raoule V. tweeted "@snobbygirl17 @...     very angry
# 9900   9904  Tweet #44: @kayla tweeted "RT @babychachis: if...       annoying
#
#        Feeling
# 0        happy
# 100      happy
# 200      happy
# 300      happy
# 400      happy
# 500      happy
# 600      happy
# 700      happy
# 800      happy
# 900      happy
# 1000     happy
# 1100     happy
# 1200     happy
# 1300     happy
# 1400       sad
# 1500       sad
# 1600       sad
# 1700       sad
# 1800       sad
# 1900       sad
# 2000       sad
# 2100       sad
# 2200       sad
# 2300       sad
# 2400       sad
# 2500       sad
# 2600     angry
# 2700     angry
# 2800     angry
# 2900     angry
# 3000     angry
# 3100     angry
# 3200     angry
# 3300      fear
# 3400      fear
# 3500      fear
# 3600      fear
# 3700      fear
# 3800      fear
# 3900      fear
# 4000   disgust
# 4100   disgust
# 4200   disgust
# 4300   disgust
# 4400   disgust
# 4500     happy
# 4600     happy
# 4700     happy
# 4800     happy
# 4900      fear
# 5000     happy
# 5100     angry
# 5200     happy
# 5300     happy
# 5400      fear
# 5500     happy
# 5600       sad
# 5700     happy
# 5800     angry
# 5900       sad
# 6000     angry
# 6100     happy
# 6200       sad
# 6300     happy
# 6400     happy
# 6500     happy
# 6600     happy
# 6700     happy
# 6800     happy
# 6900     happy
# 7000     happy
# 7100     happy
# 7200     happy
# 7300     happy
# 7400     happy
# 7500  surprise
# 7600  surprise
# 7700  surprise
# 7800  surprise
# 7900     happy
# 8000     happy
# 8100     happy
# 8200     happy
# 8300     happy
# 8400     happy
# 8500       sad
# 8600       sad
# 8700       sad
# 8800       sad
# 8900       sad
# 9000       sad
# 9100       sad
# 9200       sad
# 9300       sad
# 9400       sad
# 9500       sad
# 9600       sad
# 9700       sad
# 9800     angry
# 9900     angry

# %% [markdown]
# içe aktarılan duygu veri setine göz atalım.

# %% [markdown]
# # **Veri Seti Özeti**

# %%
# Veri setinin istatistiksel özetini görüntüleme
dataset.describe(include='all')

# 'Tweets' sütunundaki metinlerin uzunluklarını hesaplayarak 'length' adında yeni bir özellik ekleyin
dataset['length'] = dataset['Tweets'].apply(len)

# Veri setinin ilk birkaç satırını görüntüleme
dataset.head()

# Metin uzunluklarına göre duygu sınıflarının dağılımını görselleştirme
# sns.FacetGrid kullanarak duygu sınıflarına göre grafikler oluşturma
graph = sns.FacetGrid(data=dataset, col='Feeling')
# Grafiklere histogramlar ekleme ve 'length' özelliğini kullanarak metin uzunluklarını gösterme
graph.map(plt.hist, 'length', bins=20, color='Green')

# %% [markdown]
# # **İncelemelerdeki Yıldız Sayılarına Göre Oy Sütunlarının Ortalama Değerlerini Almak**

# %%
# Duygu sınıflarına göre gruplayarak ortalamaları hesaplayın
val = df.groupby('Feeling').mean()

# Ortalama değerleri ekrana yazdırın
print(val)
# Out:
#                length       Value
# Feeling
# angry     4932.246085  165.794183
# disgust   4262.874411  170.572998
# fear      4122.549247  152.156431
# happy     4560.091141  160.319501
# sad       5739.734995  161.599158
# surprise  7632.000000  136.441103

# %% [markdown]
# **OY SÜTUNLARI ARASINDAKİ KORELASYONU BULMAK**

# %%
val.corr()
# Out:
#           length     Value
# length  1.000000 -0.742981
# Value  -0.742981  1.000000

# %%
# 'Feeling' sütunundaki duygu etiketlerinin sayısını hesaplayın ve her bir duygu etiketinin sayısını görüntüleyin
dataset.Feeling.value_counts()
# Out:
# Feeling
# happy       3928
# sad         2849
# angry       1341
# fear         863
# disgust      637
# surprise     399
# Name: count, dtype: int64

# %% [markdown]
# **VERİ SETİNİ GÖRSELLEŞTİRME**

# %%
# Duygu inceleme sayısı dağılımını görselleştirme
plt.title('Duygu İnceleme Sayısı Dağılımı')

# 'Feeling' sütununa göre gruplayarak her bir duygu sınıfının inceleme sayısını hesaplayın
Sentiment_val = dataset.groupby('Feeling').count()

# Her bir duygu sınıfının inceleme sayısını çubuk grafik olarak gösterme
plt.bar(Sentiment_val.index.values, Sentiment_val['Tweets'])

# Eksen etiketlerini ve başlığı ekleme
plt.xlabel('Duygu')
plt.ylabel('İnceleme Sayısı')
plt.show()

# %% [markdown]
# **Veri Setimizden Semboller ve Sayılar Gibi İstenmeyen Unsurları Kaldırmak İçin Tokenizer Kullanma**

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import RegexpTokenizer

# Özel belirteç oluşturma
token = RegexpTokenizer(r'[a-zA-Z0-9]+')

# CountVectorizer kullanarak metin vektörlerine dönüştürme
cv = CountVectorizer(lowercase=True, stop_words='english', ngram_range=(1,1), tokenizer=token.tokenize, token_pattern=None)
text_counts = cv.fit_transform(dataset['Tweets'])

# TfidfVectorizer kullanarak metin vektörlerine dönüştürme
tf = TfidfVectorizer(tokenizer=token.tokenize, token_pattern=None)
text_tf = tf.fit_transform(dataset['Tweets'])

# %% [markdown]
# # **Eğitim ve Test Verileri**

# %%
# Bağımsız değişkenleri (x) ve bağımlı değişkeni (y) belirleme
x = text_tf  # Metin verileri vektörleri
y = dataset['Feeling']  # Duygu etiketleri

# Veri setini eğitim ve test setlerine ayırma
# test_size: test setinin oranı, random_state: rastgelelik kontrolü için kullanılan tohum
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# # **Karar Ağacı Sınıflandırıcısını Uygulama**

# %%
# Decision Tree sınıflandırıcı nesnesi oluşturma
dt = DecisionTreeClassifier()

# Oluşturulan modeli eğitim verisiyle eğitme
dt.fit(x_train, y_train)

# Test seti üzerinde tahmin yapma
preddt = dt.predict(x_test)

# Karışıklık matrisi (confusion matrix) hesaplama ve ekrana yazdırma
print("Karışıklık Matrisi (Confusion Matrix) for Decision Tree:")
print(confusion_matrix(y_test, preddt))
# Out:
# Karışıklık Matrisi (Confusion Matrix) for Decision Tree:
# [[ 360    0    2   24    9    0]
#  [   0  179    1   17    1    0]
#  [   1    1  213   28    5    2]
#  [  13    5   29 1121   44   10]
#  [  15    2    6   60  740    7]
#  [   0    1    0   12    4   94]]

# %% [markdown]
# # **Doğruluk Skoru**

# %%
# Tahmin edilen değerlerle gerçek değerler arasındaki doğruluk puanını hesaplayın
score = round(accuracy_score(y_test, preddt) * 100, 2)

# Doğruluk puanını ekrana yazdırma
print("Score:", score)
# Out:
# Score: 90.05

# %% [markdown]
# # **Sınıflandırma Raporu**

# %%
# Sınıflandırma raporunu ekrana yazdırma
print("Sınıflandırma Raporu:")
print(classification_report(y_test, preddt))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.93      0.91      0.92       395
#      disgust       0.95      0.90      0.93       198
#         fear       0.85      0.85      0.85       250
#        happy       0.89      0.92      0.90      1222
#          sad       0.92      0.89      0.91       830
#     surprise       0.83      0.85      0.84       111
#
#     accuracy                           0.90      3006
#    macro avg       0.89      0.89      0.89      3006
# weighted avg       0.90      0.90      0.90      3006
